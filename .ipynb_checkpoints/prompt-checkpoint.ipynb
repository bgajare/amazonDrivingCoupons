# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
coupons_df = pd.read_csv('data/coupons.csv')

# %%
coupons_df.info()
coupons_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
# List all the columns that have NaN values in them.
cols_with_na = coupons_df.columns[coupons_df.isna().any()].tolist()
print(cols_with_na)
# Out:
# ['car', 'Bar', 'CoffeeHouse', 'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50']

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
# For each column we can count the number of rows with missing values, and also plot a bar chat with
# the distribution of the remaining values.
for col in cols_with_na:
    nan_count = coupons_df[col].isna().sum()
    print ("column ", col, " has ", nan_count, " na values")

    # It is interesting to note that the 'car' column has 12576 rows with na values.
    # Lets examine this closely and find out all unique values for this column and also plot a bar chart
    car_values = coupons_df[col].unique()
    print(car_values)
    sns.countplot(data=coupons_df, x=col)
    title = "Distribution of ", col, " Column values for coupons data"
    plt.title(title)
    plt.xticks(rotation=45)
    plt.show()

# There are a lot of na values for the car column. If we assume that these users were not driving, the dataset will reduce drastically.
# Lets assume that when na are present in the 'car' column, the user is still driving but the car model is not known
# for ease of handling the dataframe later, lets change na values in 'car' to 'unknown' 
coupons_curated_df  = coupons_df.fillna({'car':'Unknown'})

# Lets see the distriburation again with curated values. 
sns.countplot(data=coupons_curated_df, x="car")
plt.title("Distribution of car Column values (Nan replaced with Unknown) for coupons data")
plt.xticks(rotation=45)
plt.show()

# Looking at the distribution, we found that a large proportion of data has the car values as Nan.
# For future use, we will ignore the nan values for car and use the curated dataframe where the na car values are replaced to unknown
# Morever, using the column 'car' may not really provide any valuable insight. We could as well drop it.

coupons_curated_df = coupons_curated_df.drop('car', axis=1) # axis = 1 is required to drop the column and not the rows

# we have decided to leave the other nan values as-is
# since they are less in propotion and we do not know yet if it is valid for them to be NaN
# Out:
# column  car  has  12576  na values
# [nan 'Scooter and motorcycle' 'crossover' 'Mazda5' 'do not drive'
#  'Car that is too old to install Onstar :D']
# column  Bar  has  107  na values
# ['never' 'less1' '1~3' 'gt8' nan '4~8']
# column  CoffeeHouse  has  217  na values
# ['never' 'less1' '4~8' '1~3' 'gt8' nan]
# column  CarryAway  has  151  na values
# [nan '4~8' '1~3' 'gt8' 'less1' 'never']
# column  RestaurantLessThan20  has  130  na values
# ['4~8' '1~3' 'less1' 'gt8' nan 'never']
# column  Restaurant20To50  has  189  na values
# ['1~3' 'less1' 'never' 'gt8' '4~8' nan]

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
coupons_curated_df.info()

# From the above analysis, we know there are no NaN values in the 'Y' column
print (coupons_curated_df['Y'].value_counts())
       
accepted = coupons_curated_df['Y'].value_counts()[1]
rejected = coupons_curated_df['Y'].value_counts()[0]
print ("users accepted the coupon = ",accepted, "and rejected =",rejected)

proportion_accepted = accepted / (accepted + rejected)

print ("Proportion of users that accepted the coupon = ", proportion_accepted)

proportions = coupons_curated_df['Y'].value_counts(normalize=True)

print(proportions)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  Bar                   12577 non-null  object
# ...

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
sns.countplot(data=coupons_curated_df, x="coupon")
plt.title("Bar plot of the column 'coupon")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.histplot(coupons_curated_df, x='temperature')

px.histogram(coupons_curated_df, x='temperature')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_coupons_df = coupons_curated_df.query('coupon == "Bar"')
bar_coupons_df.head()

print ("Bar coupons count = ", len(bar_coupons_df))
# Out:
# Bar coupons count =  2017

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %%
bar_accepted = bar_coupons_df['Y'].value_counts()[1]
bar_rejected = bar_coupons_df['Y'].value_counts()[0]
print ("users accepted the bar coupon = ", bar_accepted, "and rejected =", bar_rejected)

prop_bar_accepted = bar_accepted / (bar_accepted + bar_rejected)

print("proportion of bar coupons that were accepted", prop_bar_accepted)
# Out:
# users accepted the bar coupon =  827 and rejected = 1190
# proportion of bar coupons that were accepted 0.41001487357461575

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
# First get all the rows where person went to bar 3 or fewer times a month
three_or_fewer = bar_coupons_df.query('Bar == "1~3" | Bar == "less1" | Bar == "never"') 

# Not get all the rows where person wetn to bar more than 3 times
more_than_three = bar_coupons_df.query('Bar == "gt8" | Bar == "4~8" ')

# Plot both three_or_fewer and more_than_three in the same plot to easily compare.
sns.histplot(three_or_fewer, color="orange", x='Y')
sns.histplot(more_than_three, color ="lightblue", x='Y')

# we conclude that, overall there are fewer people who go to bar more than 3 times a week. 
# Also, we see that among the people who went bar less than 3 times /month, the acceptance was lower
# wheras among the people who went to bar more than 3 times /month, the acceptance was higher
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Y', ylabel='Count'>

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
# First create a filtered dataFrame with condition "drivers who go to a bar more than once a month and are over the age of 25"
filtered_df = coupons_curated_df.query('age == "46" | age == "26" | age == "31" | age == "41"  | age == "50plus" | age == "36"') 
filtered_df = filtered_df.query('Bar != "less1" & Bar != "never"')

# Then create a filtered dataFrame which will contain all the other drivers
all_others = coupons_curated_df.query('age != "46" & age != "26" | age != "31" & age != "41"  & age != "50plus" & age != "36"')
all_others = all_others.query('Bar == "less1" | Bar == "never"')

# Plot the acceptance rate together to see the pattern.
sns.histplot(three_or_fewer, color="orange", x='Y')
sns.histplot(more_than_three, color ="lightblue", x='Y')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Y', ylabel='Count'>

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %%
# First create a filtered dataFrame with the given condition 
# Drivers who go to bars more than once a month
f1_df = coupons_curated_df.query('Bar != "less1" & Bar != "never"') 
# Filter furter by drivers who had passengers that were not a kid
f1_df = f1_df.query('passanger != "Kid(s)"')
f1_df = f1_df.query('occupation != "Farming Fishing & Forestry"') 

sns.histplot(f1_df, x='Y')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# <Axes: xlabel='Y', ylabel='Count'>

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.
